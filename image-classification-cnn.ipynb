# %% [markdown]
# # Image Classification using CNN on CIFAR-10 Dataset

# %%
# importing required libraries
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score,precision_score, recall_score
from sklearn.metrics import  classification_report, f1_score, confusion_matrix

# %%
# Loading the data
cifar10 = tf.keras.datasets.cifar10

# Spliting into train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0

# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()

# %% [markdown]
# **Pixel values ranges from 0 to 255 so, we divide all input images pixel values by 255.0 to rescale it in range between 0 and 1.**

# %%
# visualize data by plotting images
fig, ax = plt.subplots(5, 5)
k = 0

for i in range(5):
      for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        k += 1

plt.show()

# %% [markdown]
# # **Building Model**

# %%
# number of classes
K = len(set(y_train))

# calculate total number of classes for output layer
print("number of classes:", K)

# Build the model using the functional API
# input layer
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

# Hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

# last output layer
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# model description
model.summary()
# Out:
# number of classes: 10
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 2397226 (9.14 MB)
# Trainable params: 2396330 (9.14 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %% [markdown]
# # **Data Augmentation**

# %%
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size

# %% [markdown]
# # **Model Compile & Fit**

# %%
model.compile(optimizer='adam',
       loss='sparse_categorical_crossentropy',
       metrics=['accuracy'])

# Fiting the model
r = model.fit(train_generator, validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch, epochs=50)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 45s 20ms/step - loss: 1.4047 - accuracy: 0.5100 - val_loss: 1.2007 - val_accuracy: 0.5853
# Epoch 2/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.9751 - accuracy: 0.6579 - val_loss: 1.0833 - val_accuracy: 0.6606
# Epoch 3/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.8348 - accuracy: 0.7126 - val_loss: 0.7345 - val_accuracy: 0.7549
# Epoch 4/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.7425 - accuracy: 0.7438 - val_loss: 0.6696 - val_accuracy: 0.7741
# Epoch 5/50
# 1562/1562 [==============================] - 31s 20ms/step - loss: 0.6755 - accuracy: 0.7702 - val_loss: 0.6525 - val_accuracy: 0.7809
# Epoch 6/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.6258 - accuracy: 0.7883 - val_loss: 0.7206 - val_accuracy: 0.7655
# Epoch 7/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.5871 - accuracy: 0.8005 - val_loss: 0.7392 - val_accuracy: 0.7561
# Epoch 8/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.5556 - accuracy: 0.8119 - val_loss: 0.5802 - val_accuracy: 0.8005
# Epoch 9/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.5213 - accuracy: 0.8211 - val_loss: 0.5189 - val_accuracy: 0.8243
# Epoch 10/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.4946 - accuracy: 0.8310 - val_loss: 0.5611 - val_accuracy: 0.8182
# Epoch 11/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.4670 - accuracy: 0.8416 - val_loss: 0.4652 - val_accuracy: 0.8416
# Epoch 12/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.4429 - accuracy: 0.8497 - val_loss: 0.5697 - val_accuracy: 0.8173
# Epoch 13/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.4296 - accuracy: 0.8522 - val_loss: 0.5877 - val_accuracy: 0.8132
# Epoch 14/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.4078 - accuracy: 0.8611 - val_loss: 0.4786 - val_accuracy: 0.8444
# Epoch 15/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3924 - accuracy: 0.8640 - val_loss: 0.5042 - val_accuracy: 0.8385
# Epoch 16/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3800 - accuracy: 0.8712 - val_loss: 0.4391 - val_accuracy: 0.8538
# Epoch 17/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3684 - accuracy: 0.8767 - val_loss: 0.4961 - val_accuracy: 0.8418
# Epoch 18/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3546 - accuracy: 0.8788 - val_loss: 0.4367 - val_accuracy: 0.8555
# Epoch 19/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3385 - accuracy: 0.8838 - val_loss: 0.4564 - val_accuracy: 0.8523
# Epoch 20/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3300 - accuracy: 0.8857 - val_loss: 0.4509 - val_accuracy: 0.8548
# Epoch 21/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3223 - accuracy: 0.8884 - val_loss: 0.4451 - val_accuracy: 0.8578
# Epoch 22/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.3085 - accuracy: 0.8947 - val_loss: 0.4548 - val_accuracy: 0.8546
# Epoch 23/50
# 1562/1562 [==============================] - 29s 19ms/step - loss: 0.3026 - accuracy: 0.8959 - val_loss: 0.4188 - val_accuracy: 0.8636
# Epoch 24/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2965 - accuracy: 0.8981 - val_loss: 0.4565 - val_accuracy: 0.8579
# Epoch 25/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2895 - accuracy: 0.9004 - val_loss: 0.4497 - val_accuracy: 0.8595
# Epoch 26/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2844 - accuracy: 0.9012 - val_loss: 0.4557 - val_accuracy: 0.8627
# Epoch 27/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2760 - accuracy: 0.9048 - val_loss: 0.4143 - val_accuracy: 0.8739
# Epoch 28/50
# 1562/1562 [==============================] - 29s 19ms/step - loss: 0.2656 - accuracy: 0.9076 - val_loss: 0.4472 - val_accuracy: 0.8565
# Epoch 29/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2619 - accuracy: 0.9095 - val_loss: 0.4017 - val_accuracy: 0.8714
# Epoch 30/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2611 - accuracy: 0.9103 - val_loss: 0.4119 - val_accuracy: 0.8687
# Epoch 31/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2500 - accuracy: 0.9138 - val_loss: 0.4156 - val_accuracy: 0.8725
# Epoch 32/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2434 - accuracy: 0.9157 - val_loss: 0.3956 - val_accuracy: 0.8761
# Epoch 33/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2384 - accuracy: 0.9179 - val_loss: 0.4310 - val_accuracy: 0.8704
# Epoch 34/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2319 - accuracy: 0.9207 - val_loss: 0.4520 - val_accuracy: 0.8689
# Epoch 35/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2289 - accuracy: 0.9208 - val_loss: 0.4168 - val_accuracy: 0.8688
# Epoch 36/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2275 - accuracy: 0.9223 - val_loss: 0.4311 - val_accuracy: 0.8701
# Epoch 37/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2222 - accuracy: 0.9248 - val_loss: 0.4395 - val_accuracy: 0.8706
# Epoch 38/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2218 - accuracy: 0.9235 - val_loss: 0.3934 - val_accuracy: 0.8805
# Epoch 39/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2150 - accuracy: 0.9244 - val_loss: 0.4456 - val_accuracy: 0.8701
# Epoch 40/50
# 1562/1562 [==============================] - 29s 19ms/step - loss: 0.2126 - accuracy: 0.9279 - val_loss: 0.4029 - val_accuracy: 0.8776
# Epoch 41/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2081 - accuracy: 0.9289 - val_loss: 0.3745 - val_accuracy: 0.8871
# Epoch 42/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2072 - accuracy: 0.9280 - val_loss: 0.3949 - val_accuracy: 0.8818
# Epoch 43/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2051 - accuracy: 0.9289 - val_loss: 0.3800 - val_accuracy: 0.8806
# Epoch 44/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.2010 - accuracy: 0.9310 - val_loss: 0.4918 - val_accuracy: 0.8614
# Epoch 45/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.1967 - accuracy: 0.9333 - val_loss: 0.4125 - val_accuracy: 0.8805
# Epoch 46/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.1907 - accuracy: 0.9337 - val_loss: 0.3974 - val_accuracy: 0.8825
# Epoch 47/50
# 1562/1562 [==============================] - 30s 19ms/step - loss: 0.1912 - accuracy: 0.9344 - val_loss: 0.3939 - val_accuracy: 0.8851
# Epoch 48/50
# 1562/1562 [==============================] - 31s 20ms/step - loss: 0.1877 - accuracy: 0.9340 - val_loss: 0.3918 - val_accuracy: 0.8811
# Epoch 49/50
# 1562/1562 [==============================] - 31s 20ms/step - loss: 0.1881 - accuracy: 0.9357 - val_loss: 0.4101 - val_accuracy: 0.8793
# Epoch 50/50
# 1562/1562 [==============================] - 31s 20ms/step - loss: 0.1849 - accuracy: 0.9367 - val_loss: 0.3903 - val_accuracy: 0.8859

# %%
# model loss and accuracy on test data
loss = model.evaluate(x_test, y_test)
print (loss)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3903 - accuracy: 0.8859
# [0.3903144598007202, 0.8859000205993652]

# %%
y_pred = model.predict(x_test)
y_pred = [np.argmax(arr) for arr in y_pred]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# reshaping the test data into 1D array
y_test = y_test.reshape(-1,)

# %%
# Printing accuracy and classification report
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.8859
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      1000
#            1       0.93      0.95      0.94      1000
#            2       0.88      0.85      0.87      1000
#            3       0.79      0.74      0.76      1000
#            4       0.89      0.86      0.87      1000
#            5       0.86      0.78      0.82      1000
#            6       0.86      0.95      0.90      1000
#            7       0.89      0.93      0.91      1000
#            8       0.92      0.95      0.94      1000
#            9       0.91      0.93      0.92      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.88      0.89      0.88     10000
# weighted avg       0.88      0.89      0.88     10000

# %% [markdown]
# # **Confusion Matrix**

# %%
cnn = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,10))
sns.heatmap(cnn, annot=True, fmt='d')
plt.ylabel("Truth")
plt.xlabel("Predictions")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# # **Learning Curve**

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %% [markdown]
# # **Image Classification System**

# %%
# label mapping

labels = '''airplane automobile bird cat deerdog frog horseship truck'''.split()

# select the image from our test dataset
image_number = 1970

# display the image
plt.imshow(x_test[image_number])

# load the image in an array
n = np.array(x_test[image_number])

# reshape it
p = n.reshape(1, 32, 32, 3)

# pass in the network for prediction and 
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]

# load the original label
original_label = labels[y_test[image_number]]

# display the result
print("Original label is {} and predicted label is {}".format(
      original_label, predicted_label))
# Out:
# 1/1 [==============================] - 0s 229ms/step
# Original label is automobile and predicted label is automobile

# %% [markdown]
# **Before sending the image to our model we need to again reduce the pixel values between 0 and 1 and change its shape to (1,32,32,3) as our model expects the input to be in this form only.**

# %%
# save the model
model.save('image-classification-cnn.h5')
